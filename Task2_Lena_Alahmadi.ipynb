# %% [markdown]
# ## Objective
# * The objective of this exercise is to explore and visualize the Traffic Index dataset to gain insights and understand the patterns in the data.

# %% [markdown]
# ##Dataset Description

# %% [markdown]
# | Column Name | Description | Data Type |
# | :---------------- | :------: | ----: |
# |   City  |   Name of the city	   | Object |
# | Datetime           |   Date and time of the data entry	   | Object |
# |  TrafficIndexLive    |  Real-time traffic index	   | Int |
# |  Jamscount |  Number of traffic jams	   | Int |
# |   JamsDelay  |   Total delay caused by traffic jams (in minutes)	   | Float |
# |JamsLength           |   Total length of traffic jams (in kilometers)	   | Float |
# |  TrafficIndexWeekAgo    |  Traffic index one week ago	   | Int |
# |  TravelTimeHistoric |  Historical average travel time (in minutes)	   | Float |
# |   TravelTimeLive  |   Real-time travel time (in minutes)	   | Float |

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df = pd.read_csv('/content/Datasets/Task (2) Dataset.csv')

# %%
df.head()
# Out:
#        City             Datetime  TrafficIndexLive  JamsCount  JamsDelay  \
# 0  Abudhabi  2023-07-07 08:01:30                 6          4       15.6
# 1  Abudhabi  2023-07-07 09:01:30                 7          7       20.5
# 2  Abudhabi  2023-07-07 10:46:30                 7          8       25.0
# 3  Abudhabi  2023-07-07 11:16:30                 8         11       30.6
# 4  Abudhabi  2023-07-07 12:01:30                 8         20       62.1
#
#    JamsLength  TrafficIndexWeekAgo  TravelTimeHistoric  TravelTimeLive
# 0         0.7                   13           59.611918       54.803617
# 1         1.7                    8           60.221387       56.118629
# 2         2.8                    6           59.161978       55.518834
# 3         5.5                    6           59.738138       56.413917
# 4         6.5                    5           58.958314       56.059246

# %%
df.tail()
# Out:
#          City             Datetime  TrafficIndexLive  JamsCount  JamsDelay  \
# 66634  Riyadh  2023-12-15 03:01:30                 8         33      127.8
# 66635  Riyadh  2023-12-15 04:31:30                 6         27       87.0
# 66636  Riyadh  2023-12-15 05:01:30                 3         17       49.8
# 66637  Riyadh  2023-12-15 06:01:30                 0         16       61.3
# 66638  Riyadh  2023-12-15 07:01:30                 0         15       39.5
#
#        JamsLength  TrafficIndexWeekAgo  TravelTimeHistoric  TravelTimeLive
# 66634        20.4                    8           63.926569       63.245473
# 66635        13.8                    5           59.182641       60.012955
# 66636         6.7                    1           57.746816       57.561438
# 66637         4.3                    0           56.535277       55.463218
# 66638         5.2                    0           56.126417       54.886055

# %%
df.shape
# Out:
# (66639, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66639 entries, 0 to 66638
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   City                 66639 non-null  object
#  1   Datetime             66639 non-null  object
#  2   TrafficIndexLive     66639 non-null  int64
#  3   JamsCount            66639 non-null  int64
#  4   JamsDelay            66639 non-null  float64
#  5   JamsLength           66639 non-null  float64
#  6   TrafficIndexWeekAgo  66639 non-null  int64
#  7   TravelTimeHistoric   62772 non-null  float64
#  8   TravelTimeLive       62772 non-null  float64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 4.6+ MB

# %%
df.describe()
# Out:
#        TrafficIndexLive     JamsCount     JamsDelay    JamsLength  \
# count      66639.000000  66639.000000  66639.000000  66639.000000
# mean          14.043113     74.278531    288.353877     49.316135
# std           13.488906    107.452022    470.013224     85.352525
# min            0.000000      0.000000      0.000000      0.000000
# 25%            3.000000      9.000000     27.700000      3.000000
# 50%           10.000000     29.000000     95.700000     12.200000
# 75%           21.000000     95.000000    336.600000     53.500000
# max          138.000000   1359.000000   9989.400000   1173.900000
#
#        TrafficIndexWeekAgo  TravelTimeHistoric  TravelTimeLive
# count         66639.000000        62772.000000    62772.000000
# mean             13.981737           70.706601       70.048451
# std              13.454922           10.588384       11.966725
# min               0.000000           49.381346       46.723235
# ...

# %%
df.isnull().sum()
# Out:
# City                      0
# Datetime                  0
# TrafficIndexLive          0
# JamsCount                 0
# JamsDelay                 0
# JamsLength                0
# TrafficIndexWeekAgo       0
# TravelTimeHistoric     3867
# TravelTimeLive         3867
# dtype: int64

# %%
df.drop('TravelTimeHistoric', axis=1, inplace=True)
df.drop('TravelTimeLive', axis=1, inplace=True)

# %%
df.isnull().sum()
# Out:
# City                   0
# Datetime               0
# TrafficIndexLive       0
# JamsCount              0
# JamsDelay              0
# JamsLength             0
# TrafficIndexWeekAgo    0
# dtype: int64

# %% [markdown]
# # Tasks

# %% [markdown]
# ## 1. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
df.describe()
# Out:
#        TrafficIndexLive     JamsCount     JamsDelay    JamsLength  \
# count      66639.000000  66639.000000  66639.000000  66639.000000
# mean          14.043113     74.278531    288.353877     49.316135
# std           13.488906    107.452022    470.013224     85.352525
# min            0.000000      0.000000      0.000000      0.000000
# 25%            3.000000      9.000000     27.700000      3.000000
# 50%           10.000000     29.000000     95.700000     12.200000
# 75%           21.000000     95.000000    336.600000     53.500000
# max          138.000000   1359.000000   9989.400000   1173.900000
#
#        TrafficIndexWeekAgo
# count         66639.000000
# mean             13.981737
# std              13.454922
# min               0.000000
# 25%               3.000000
# 50%              10.000000
# 75%              21.000000
# max             138.000000

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %%
print(df.isnull().sum())
# Out:
# City                   0
# Datetime               0
# TrafficIndexLive       0
# JamsCount              0
# JamsDelay              0
# JamsLength             0
# TrafficIndexWeekAgo    0
# dtype: int64

# %%
city_stats = df.groupby('City').mean()
print(city_stats)
# Out:
#                               Datetime  TrafficIndexLive   JamsCount  \
# City
# Abudhabi 2023-09-25 19:44:56.157867520         10.843944   29.870859
# Al-ain   2023-09-25 19:45:07.672101632          7.953416    6.837733
# Cairo    2023-06-16 13:13:09.297928704          7.710587   65.302186
# Dammam   2023-09-25 19:44:52.625258752         12.403986   33.675983
# Doha     2023-06-16 14:02:29.346065408         16.472158   41.909457
# Dubai    2023-06-16 15:18:38.900460288         22.621519  185.216341
# Jeddah   2023-09-25 19:44:04.736542464         15.374741   48.843944
# Kuwait   2023-06-16 13:42:16.427799040         13.831320   68.176619
# Mecca    2023-09-25 19:39:26.297101312          3.225932   11.925207
# Medina   2023-09-25 19:41:36.103002112          3.879917   10.631470
# Riyadh   2023-06-16 14:02:45.985273856         23.173263  145.902324
#
#            JamsDelay  JamsLength  TrafficIndexWeekAgo
# City
# Abudhabi  107.800285   14.308282            10.738613
# ...

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Traffic_Index, Date).

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x='Datetime', y='TrafficIndexLive', hue='City')
plt.title('Traffic Index Over Time')
plt.show()

# %%
# Distribution
plt.figure(figsize=(12, 6))
sns.boxplot(df['TrafficIndexLive'])
plt.title('TrafficIndexLive Distribution')
plt.xlabel('TrafficIndexLive')
plt.show()


# Distribution
plt.figure(figsize=(12, 6))
sns.boxplot(df['JamsCount'])
plt.title('JamsCount Distribution')
plt.xlabel('JamsCount')
plt.show()


# Distribution
plt.figure(figsize=(12, 6))
sns.boxplot(df['JamsDelay'])
plt.title('JamsDelay Distribution')
plt.xlabel('JamsDelay')
plt.show()


# Distribution
plt.figure(figsize=(12, 6))
sns.boxplot(df['JamsLength'])
plt.title('JamsLength Distribution')
plt.xlabel('JamsLength')
plt.show()


# Distribution
plt.figure(figsize=(12, 6))
sns.boxplot(df['TrafficIndexWeekAgo'])
plt.title('TrafficIndexWeekAgo Distribution')
plt.xlabel('TrafficIndexWeekAgo')
plt.show()

# %%
def remove_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]

df = remove_outliers(df, "TrafficIndexLive")
df = remove_outliers(df, "JamsCount")
df = remove_outliers(df, "JamsDelay")
df = remove_outliers(df, "JamsLength")
df = remove_outliers(df, "TrafficIndexWeekAgo")

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
dff_typr = df['City'].value_counts()
plt.pie(dff_typr, labels=dff_typr.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x78115e968430>,
# ...
#  [Text(1.0089333361220603, 0.4382391165352652, 'Doha'),
#   Text(0.3683739908713773, 1.036484733534216, 'Riyadh'),
#   Text(-0.5060154206352397, 0.9767028176878275, 'Kuwait'),
#   Text(-1.059148745282201, 0.2969914735596622, 'Cairo'),
#   Text(-0.9400874326118202, -0.5711703940553263, 'Dubai'),
#   Text(-0.4615445978171946, -0.9984871477519198, 'Abudhabi'),
#   Text(-0.07547169529773957, -1.0974078654761343, 'Al-ain'),
#   Text(0.32050843245355337, -1.0522710414746603, 'Dammam'),
#   Text(0.6744151813507772, -0.8690018200001646, 'Jeddah'),
#   Text(0.9397909508516352, -0.571658087231677, 'Mecca'),
#   Text(1.081799667522965, -0.19927237477182505, 'Medina')])

# %% [markdown]
# ### Explore relationships between variables (e.g., Traffic_Index vs. Weather_Condition).

# %%
sns.pairplot(df)

# %%
numerical_df = df.select_dtypes(include=['number'])

correlation_matrix = numerical_df.corr()
correlation_matrix
# Out:
#                      TrafficIndexLive  JamsCount  JamsDelay  JamsLength  \
# TrafficIndexLive             1.000000   0.876216   0.861349    0.866799
# JamsCount                    0.876216   1.000000   0.982459    0.952762
# JamsDelay                    0.861349   0.982459   1.000000    0.962679
# JamsLength                   0.866799   0.952762   0.962679    1.000000
# TrafficIndexWeekAgo          0.903282   0.806545   0.775028    0.787548
#
#                      TrafficIndexWeekAgo
# TrafficIndexLive                0.903282
# JamsCount                       0.806545
# JamsDelay                       0.775028
# JamsLength                      0.787548
# TrafficIndexWeekAgo             1.000000

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='TrafficIndexLive', y='JamsCount') # Make sure 'JamsCount' matches the actual column name in your DataFrame
plt.title('Relationship between Traffic Index Live and Jams Count')
plt.xlabel('Traffic Index Live')
plt.ylabel('Jams Count')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='TrafficIndexLive', y='JamsDelay') # Assuming 'JamsDelay' is the correct column name
plt.title('Relationship between Traffic Index Live and Jams Delay')
plt.xlabel('Traffic Index Live')
plt.ylabel('Jams Delay')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='JamsCount', y='JamsDelay')
plt.title('Relationship between Jams Count and Jams Delay')
plt.xlabel('Jams Count')
plt.ylabel('Jams Delay')
plt.show()

# %% [markdown]
# ## 2. Data Visualization

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %%
sns.histplot(df['City'], kde=True, bins=20, color='red')
# Out:
# <Axes: xlabel='City', ylabel='Count'>

# %%
numerical_df = df.select_dtypes(include=['number'])
corr_matrix = numerical_df.corr()
sns.heatmap(corr_matrix, annot=True)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %%
df.hist(figsize=(15,12))
# Out:
# array([[<Axes: title={'center': 'Datetime'}>,
#         <Axes: title={'center': 'TrafficIndexLive'}>],
#        [<Axes: title={'center': 'JamsCount'}>,
#         <Axes: title={'center': 'JamsDelay'}>],
#        [<Axes: title={'center': 'JamsLength'}>,
#         <Axes: title={'center': 'TrafficIndexWeekAgo'}>]], dtype=object)

# %%
df.plot.hexbin(x= 'JamsDelay' , y='JamsCount' , gridsize = 15 )
# Out:
# <Axes: xlabel='JamsDelay', ylabel='JamsCount'>

# %% [markdown]
# ## 3. Insights and Conclusions

# %% [markdown]
# * <h3>Summarize the key insights gained from the data analysis.<h3/>
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>

# %% [markdown]
# Based on the statistic Traffic congestion varies significantly across cities and time
